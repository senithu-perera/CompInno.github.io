# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
import sklearn as skl

# %%
data = pd.read_csv("database/csv2.csv")
data
# Out:
#            Suburb              Address  Rooms Type      Price Method  SellerG  \
# 0      Abbotsford      25 Bloomburg St      2    h  1035000.0      S   Biggin
# 1      Abbotsford         5 Charles St      3    h  1465000.0     SP   Biggin
# 2      Abbotsford          55a Park St      4    h  1600000.0     VB   Nelson
# 3      Abbotsford         16 Maugie St      4    h   870000.0     SN   Nelson
# 4      Abbotsford  121/56 Nicholson St      2    u   870000.0     PI   Biggin
# ...           ...                  ...    ...  ...        ...    ...      ...
# 10509     Wollert      35 Kingscote Wy      3    h   570000.0     SP       RW
# 10510     Wollert     15 Rockgarden Wy      3    h   870000.0     SP       LJ
# 10511  Yarraville        29A Murray St      2    h   888000.0     SP  Sweeney
# 10512  Yarraville       147A Severn St      2    t   705000.0      S      Jas
# 10513  Yarraville     3 Tarrengower St      2    h  1020000.0     PI       RW
#
#              Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# 0      2016-02-04       2.5    3067.0  ...       1.0  0.0     156.0
# 1      2017-03-04       2.5    3067.0  ...       2.0  0.0     134.0
# 2      2016-06-04       2.5    3067.0  ...       1.0  2.0     120.0
# 3      2016-08-06       2.5    3067.0  ...       2.0  2.0     400.0
# 4      2016-11-07       2.5    3067.0  ...       2.0  1.0    4292.0
# ...           ...       ...       ...  ...       ...  ...       ...
# 10509  2018-02-24      25.5    3750.0  ...       2.0  2.0     404.0
# 10510  2018-02-24      25.5    3750.0  ...       2.0  2.0     268.0
# 10511  2018-02-24       6.3    3013.0  ...       2.0  1.0      98.0
# 10512  2018-02-24       6.3    3013.0  ...       1.0  2.0     220.0
# 10513  2018-02-24       6.3    3013.0  ...       1.0  0.0     250.0
#
#        BuildingArea  YearBuilt               CouncilArea Lattitude  \
# 0              79.0     1900.0        Yarra City Council -37.80790
# 1             150.0     1900.0        Yarra City Council -37.80930
# 2             142.0     2014.0        Yarra City Council -37.80720
# 3             220.0     2006.0        Yarra City Council -37.79650
# 4              82.0     2009.0        Yarra City Council -37.80780
# ...             ...        ...                       ...       ...
# 10509         158.0     2012.0   Whittlesea City Council -37.61031
# 10510         135.0     2016.0   Whittlesea City Council -37.61094
# 10511         104.0     2018.0  Maribyrnong City Council -37.81551
# 10512         120.0     2000.0  Maribyrnong City Council -37.82286
# 10513         103.0     1930.0  Maribyrnong City Council -37.81810
#
#        Longtitude             Regionname Propertycount
# 0       144.99340  Northern Metropolitan        4019.0
# 1       144.99440  Northern Metropolitan        4019.0
# 2       144.99410  Northern Metropolitan        4019.0
# 3       144.99650  Northern Metropolitan        4019.0
# 4       144.99650  Northern Metropolitan        4019.0
# ...           ...                    ...           ...
# 10509   145.03393  Northern Metropolitan        2940.0
# 10510   145.04281  Northern Metropolitan        2940.0
# 10511   144.88826   Western Metropolitan        6543.0
# 10512   144.87856   Western Metropolitan        6543.0
# 10513   144.89351   Western Metropolitan        6543.0
#
# [10514 rows x 21 columns]

# %% [markdown]
# <strong>Checking for Nan Values</strong>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10514 entries, 0 to 10513
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         10514 non-null  object
#  1   Address        10514 non-null  object
#  2   Rooms          10514 non-null  int64
#  3   Type           10514 non-null  object
#  4   Price          10514 non-null  float64
#  5   Method         10514 non-null  object
#  6   SellerG        10514 non-null  object
#  7   Date           10514 non-null  object
#  8   Distance       10514 non-null  float64
#  9   Postcode       10514 non-null  float64
#  10  Bedroom2       10514 non-null  float64
#  11  Bathroom       10514 non-null  float64
#  12  Car            10514 non-null  float64
#  13  Landsize       10514 non-null  float64
#  14  BuildingArea   10514 non-null  float64
#  15  YearBuilt      10514 non-null  float64
#  16  CouncilArea    10514 non-null  object
#  17  Lattitude      10514 non-null  float64
#  18  Longtitude     10514 non-null  float64
#  19  Regionname     10514 non-null  object
#  20  Propertycount  10514 non-null  float64
# dtypes: float64(12), int64(1), object(8)
# memory usage: 1.7+ MB

# %% [markdown]
# <strong>Droping the Nan Values</strong>

# %%
data.dropna(inplace=True)

# %% [markdown]
# <strong>Spliting the train and test data</strong>

# %%
from sklearn.model_selection import train_test_split

X = data.drop(['Price'], axis=1)
Y = data['Price']

X
# Out:
#            Suburb              Address  Rooms Type Method  SellerG  \
# 0      Abbotsford      25 Bloomburg St      2    h      S   Biggin
# 1      Abbotsford         5 Charles St      3    h     SP   Biggin
# 2      Abbotsford          55a Park St      4    h     VB   Nelson
# 3      Abbotsford         16 Maugie St      4    h     SN   Nelson
# 4      Abbotsford  121/56 Nicholson St      2    u     PI   Biggin
# ...           ...                  ...    ...  ...    ...      ...
# 10509     Wollert      35 Kingscote Wy      3    h     SP       RW
# 10510     Wollert     15 Rockgarden Wy      3    h     SP       LJ
# 10511  Yarraville        29A Murray St      2    h     SP  Sweeney
# 10512  Yarraville       147A Severn St      2    t      S      Jas
# 10513  Yarraville     3 Tarrengower St      2    h     PI       RW
#
#              Date  Distance  Postcode  Bedroom2  Bathroom  Car  Landsize  \
# 0      2016-02-04       2.5    3067.0       2.0       1.0  0.0     156.0
# 1      2017-03-04       2.5    3067.0       3.0       2.0  0.0     134.0
# 2      2016-06-04       2.5    3067.0       3.0       1.0  2.0     120.0
# 3      2016-08-06       2.5    3067.0       3.0       2.0  2.0     400.0
# 4      2016-11-07       2.5    3067.0       2.0       2.0  1.0    4292.0
# ...           ...       ...       ...       ...       ...  ...       ...
# 10509  2018-02-24      25.5    3750.0       3.0       2.0  2.0     404.0
# 10510  2018-02-24      25.5    3750.0       3.0       2.0  2.0     268.0
# 10511  2018-02-24       6.3    3013.0       2.0       2.0  1.0      98.0
# 10512  2018-02-24       6.3    3013.0       2.0       1.0  2.0     220.0
# 10513  2018-02-24       6.3    3013.0       2.0       1.0  0.0     250.0
#
#        BuildingArea  YearBuilt               CouncilArea  Lattitude  \
# 0              79.0     1900.0        Yarra City Council  -37.80790
# 1             150.0     1900.0        Yarra City Council  -37.80930
# 2             142.0     2014.0        Yarra City Council  -37.80720
# 3             220.0     2006.0        Yarra City Council  -37.79650
# 4              82.0     2009.0        Yarra City Council  -37.80780
# ...             ...        ...                       ...        ...
# 10509         158.0     2012.0   Whittlesea City Council  -37.61031
# 10510         135.0     2016.0   Whittlesea City Council  -37.61094
# 10511         104.0     2018.0  Maribyrnong City Council  -37.81551
# 10512         120.0     2000.0  Maribyrnong City Council  -37.82286
# 10513         103.0     1930.0  Maribyrnong City Council  -37.81810
#
#        Longtitude             Regionname  Propertycount
# 0       144.99340  Northern Metropolitan         4019.0
# 1       144.99440  Northern Metropolitan         4019.0
# 2       144.99410  Northern Metropolitan         4019.0
# 3       144.99650  Northern Metropolitan         4019.0
# 4       144.99650  Northern Metropolitan         4019.0
# ...           ...                    ...            ...
# 10509   145.03393  Northern Metropolitan         2940.0
# 10510   145.04281  Northern Metropolitan         2940.0
# 10511   144.88826   Western Metropolitan         6543.0
# 10512   144.87856   Western Metropolitan         6543.0
# 10513   144.89351   Western Metropolitan         6543.0
#
# [10514 rows x 20 columns]

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)

# %% [markdown]
# <strong>Analising Basic Correlation</strong>

# %%
train_data = X_train.join(Y_train)
train_data
# Out:
#                Suburb            Address  Rooms Type Method    SellerG  \
# 9586   Bentleigh East          1 Vine Ct      5    h      S     Jellis
# 7985   West Footscray   22 Carmichael St      3    h     PI    Burnham
# 3748         St Kilda  52/167 Fitzroy St      3    t      S     Rodney
# 10084          Doreen      38 Orchard Rd      3    u      S  Harcourts
# 9459          Wollert      21 Dalwood Wy      4    h      S        HAR
# ...               ...                ...    ...  ...    ...        ...
# 65        Albert Park    364 Montague St      2    h      S       Greg
# 3800       Strathmore         9 Marks St      3    h      S  Considine
# 389      Balwyn North        47 Ellsa St      4    h     SN         RT
# 7476     Moonee Ponds     86 Waverley St      3    h     PI    Sweeney
# 20         Abbotsford         49 Park St      2    h      S   Marshall
#
#              Date  Distance  Postcode  Bedroom2  ...  Car  Landsize  \
# 9586   2018-03-03      13.8    3165.0       5.0  ...  2.0     400.0
# 7985   2017-09-23       6.4    3012.0       3.0  ...  1.0     365.0
# 3748   2016-07-16       6.1    3182.0       3.0  ...  2.0       0.0
# 10084  2018-03-17      25.9    3754.0       3.0  ...  2.0     315.0
# 9459   2017-12-09      25.5    3750.0       4.0  ...  2.0     350.0
# ...           ...       ...       ...       ...  ...  ...       ...
# 65     2016-10-15       3.3    3206.0       2.0  ...  0.0     141.0
# 3800   2016-06-18       9.7    3041.0       3.0  ...  2.0     211.0
# 389    2016-11-12       9.2    3104.0       4.0  ...  1.0    1088.0
# 7476   2017-09-03       6.2    3039.0       3.0  ...  0.0     411.0
# 20     2016-11-19       2.5    3067.0       2.0  ...  0.0     147.0
#
#        BuildingArea  YearBuilt                 CouncilArea Lattitude  \
# 9586          260.0     2013.0      Glen Eira City Council -37.91653
# 7985          137.0     1970.0    Maribyrnong City Council -37.79865
# 3748          200.0     2000.0   Port Phillip City Council -37.85840
# 10084         120.0     2013.0     Nillumbik Shire Council -37.61202
# 9459            0.0     2015.0     Whittlesea City Council -37.61031
# ...             ...        ...                         ...       ...
# 65             83.0     1890.0   Port Phillip City Council -37.84240
# 3800           46.0     1980.0  Moonee Valley City Council -37.73400
# 389           197.0     1950.0     Boroondara City Council -37.79560
# 7476          114.0     1915.0  Moonee Valley City Council -37.76285
# 20             85.0     1900.0          Yarra City Council -37.80800
#
#        Longtitude             Regionname Propertycount      Price
# 9586    145.05705  Southern Metropolitan       10969.0  1669000.0
# 7985    144.87787   Western Metropolitan        5058.0   870000.0
# 3748    144.98020  Southern Metropolitan       13240.0  1295000.0
# 10084   145.13012      Northern Victoria        7254.0   530000.0
# 9459    145.04010  Northern Metropolitan        2940.0   609000.0
# ...           ...                    ...           ...        ...
# 65      144.95620  Southern Metropolitan        3280.0  1562500.0
# 3800    144.91450   Western Metropolitan        3284.0  1080000.0
# 389     145.09620  Southern Metropolitan        7809.0   870000.0
# 7476    144.90575   Western Metropolitan        6232.0  1210000.0
# 20      144.99400  Northern Metropolitan        4019.0  1315000.0
#
# [8411 rows x 21 columns]

# %%
train_data.Suburb.value_counts()
# Out:
# Suburb
# Reservoir          165
# Richmond           147
# Coburg             142
# Bentleigh East     135
# Brunswick          120
#                   ...
# Patterson Lakes      1
# Bacchus Marsh        1
# The Basin            1
# Gisborne South       1
# Botanic Ridge        1
# Name: count, Length: 315, dtype: int64

# %%
pd.get_dummies(train_data.Suburb)
# Out:
#        Abbotsford  Aberfeldie  Airport West  Albanvale  Albert Park  Albion  \
# 9586        False       False         False      False        False   False
# 7985        False       False         False      False        False   False
# 3748        False       False         False      False        False   False
# 10084       False       False         False      False        False   False
# 9459        False       False         False      False        False   False
# ...           ...         ...           ...        ...          ...     ...
# 65          False       False         False      False         True   False
# 3800        False       False         False      False        False   False
# 389         False       False         False      False        False   False
# 7476        False       False         False      False        False   False
# 20           True       False         False      False        False   False
#
#        Alphington  Altona  Altona Meadows  Altona North  ...  Whittlesea  \
# 9586        False   False           False         False  ...       False
# 7985        False   False           False         False  ...       False
# 3748        False   False           False         False  ...       False
# 10084       False   False           False         False  ...       False
# 9459        False   False           False         False  ...       False
# ...           ...     ...             ...           ...  ...         ...
# 65          False   False           False         False  ...       False
# 3800        False   False           False         False  ...       False
# 389         False   False           False         False  ...       False
# 7476        False   False           False         False  ...       False
# 20          False   False           False         False  ...       False
#
#        Williams Landing  Williamstown  Williamstown North  Windsor  Wollert  \
# 9586              False         False               False    False    False
# 7985              False         False               False    False    False
# 3748              False         False               False    False    False
# 10084             False         False               False    False    False
# 9459              False         False               False    False     True
# ...                 ...           ...                 ...      ...      ...
# 65                False         False               False    False    False
# 3800              False         False               False    False    False
# 389               False         False               False    False    False
# 7476              False         False               False    False    False
# 20                False         False               False    False    False
#
#        Wyndham Vale  Yallambie  Yarra Glen  Yarraville
# 9586          False      False       False       False
# 7985          False      False       False       False
# 3748          False      False       False       False
# 10084         False      False       False       False
# 9459          False      False       False       False
# ...             ...        ...         ...         ...
# 65            False      False       False       False
# 3800          False      False       False       False
# 389           False      False       False       False
# 7476          False      False       False       False
# 20            False      False       False       False
#
# [8411 rows x 315 columns]

# %% [markdown]
# <strong>Checking the Distribution between the feature colomns</strong>

# %%
train_data.hist(figsize=(15, 13))
# Out:
# array([[<Axes: title={'center': 'Rooms'}>,
#         <Axes: title={'center': 'Distance'}>,
#         <Axes: title={'center': 'Postcode'}>,
#         <Axes: title={'center': 'Bedroom2'}>],
#        [<Axes: title={'center': 'Bathroom'}>,
#         <Axes: title={'center': 'Car'}>,
#         <Axes: title={'center': 'Landsize'}>,
#         <Axes: title={'center': 'BuildingArea'}>],
#        [<Axes: title={'center': 'YearBuilt'}>,
#         <Axes: title={'center': 'Lattitude'}>,
#         <Axes: title={'center': 'Longtitude'}>,
#         <Axes: title={'center': 'Propertycount'}>],
#        [<Axes: title={'center': 'Price'}>, <Axes: >, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
# Exclude non-numeric columns before calculating correlation
numeric_columns = train_data.select_dtypes(include=['number']).columns
numeric_train_data = train_data[numeric_columns]

#correlation on numeric data
correlation_matrix = numeric_train_data.corr()
correlation_matrix
# Out:
#                   Rooms  Distance  Postcode  Bedroom2  Bathroom       Car  \
# Rooms          1.000000  0.317974  0.090605  0.966820  0.610726  0.403830
# Distance       0.317974  1.000000  0.500168  0.327510  0.165115  0.291727
# Postcode       0.090605  0.500168  1.000000  0.093192  0.122894  0.070698
# Bedroom2       0.966820  0.327510  0.093192  1.000000  0.613403  0.407305
# Bathroom       0.610726  0.165115  0.122894  0.613403  1.000000  0.323580
# Car            0.403830  0.291727  0.070698  0.407305  0.323580  1.000000
# Landsize       0.078986  0.142446  0.081821  0.080186  0.065395  0.110323
# BuildingArea   0.647829  0.201129  0.093933  0.637394  0.578649  0.342255
# YearBuilt      0.013502  0.303705  0.100239  0.024770  0.207824  0.154202
# Lattitude      0.024539 -0.084502 -0.200453  0.030647 -0.038989  0.009664
# Longtitude     0.084375  0.198445  0.367641  0.085647  0.103664  0.043185
# Propertycount -0.079276 -0.011683  0.031813 -0.078981 -0.053654 -0.028689
# Price          0.342805 -0.180099 -0.015209  0.329950  0.248520  0.116239
#
#                Landsize  BuildingArea  YearBuilt  Lattitude  Longtitude  \
# Rooms          0.078986      0.647829   0.013502   0.024539    0.084375
# Distance       0.142446      0.201129   0.303705  -0.084502    0.198445
# Postcode       0.081821      0.093933   0.100239  -0.200453    0.367641
# Bedroom2       0.080186      0.637394   0.024770   0.030647    0.085647
# Bathroom       0.065395      0.578649   0.207824  -0.038989    0.103664
# Car            0.110323      0.342255   0.154202   0.009664    0.043185
# Landsize       1.000000      0.077933   0.044789   0.051509   -0.009292
# BuildingArea   0.077933      1.000000   0.074862  -0.021217    0.090681
# YearBuilt      0.044789      0.074862   1.000000   0.084107   -0.027288
# Lattitude      0.051509     -0.021217   0.084107   1.000000   -0.350872
# Longtitude    -0.009292      0.090681  -0.027288  -0.350872    1.000000
# Propertycount -0.028054     -0.057030   0.014373   0.003642    0.017562
# Price          0.014607      0.315127  -0.306309  -0.183297    0.202219
#
#                Propertycount     Price
# Rooms              -0.079276  0.342805
# Distance           -0.011683 -0.180099
# Postcode            0.031813 -0.015209
# Bedroom2           -0.078981  0.329950
# Bathroom           -0.053654  0.248520
# Car                -0.028689  0.116239
# Landsize           -0.028054  0.014607
# BuildingArea       -0.057030  0.315127
# YearBuilt           0.014373 -0.306309
# Lattitude           0.003642 -0.183297
# Longtitude          0.017562  0.202219
# Propertycount       1.000000 -0.083118
# Price              -0.083118  1.000000

# %% [markdown]
# <strong>Building Correlation matix Heatmap</strong>

# %%
plt.figure(figsize=(15, 8))
sns.heatmap(correlation_matrix, annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %% [markdown]
# <h1><strong>Model Devolopment - Linear Regressor Model</strong></h1>

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

numeric_columns = train_data.select_dtypes(include=['number']).columns
numeric_train_data = train_data[numeric_columns]
x_train, y_train = numeric_train_data.drop(['Price'], axis=1), numeric_train_data['Price']
x_train_s = scaler.fit_transform(x_train)

regressor = LinearRegression()
regressor.fit(x_train_s, y_train)
# Out:
# LinearRegression()

# %%
test_data = X_test.join(Y_test)

numeric_columns = test_data.select_dtypes(include=['number']).columns
numeric_test_data = test_data[numeric_columns]

X_test, Y_test = numeric_test_data.drop(['Price'], axis=1), numeric_test_data['Price']

Y_test
# Out:
# 3660     680500.0
# 2062     350000.0
# 4490     870000.0
# 9611     870000.0
# 5661     827000.0
#           ...
# 8839     870000.0
# 963      870000.0
# 2169     900000.0
# 4910    1355000.0
# 7519     870000.0
# Name: Price, Length: 2103, dtype: float64

# %%
X_test_s = scaler.transform(X_test)

# %%
regressor.predict(X_test_s)

regressor.score(X_test_s, Y_test)
# Out:
# 0.33391494134114075

# %% [markdown]
# <h1><strong>Model Devolopment - Random Forest Regressor</strong></h1>

# %%
from sklearn.ensemble import RandomForestRegressor

forest_regressor = RandomForestRegressor()

forest_regressor.fit(x_train_s, y_train)
# Out:
# RandomForestRegressor()

# %%
forest_regressor.score(X_test_s, Y_test)
# Out:
# 0.5463958507637819

# %% [markdown]
# <strong>Grid Search Cross Validation for more model Accuracy</strong>

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    "n_estimators": [3, 10, 30],
    "max_features": [2, 4, 6, 8]
}

grid_search = GridSearchCV(forest_regressor, param_grid, cv=5, scoring="neg_mean_squared_error", return_train_score=True)
grid_search.fit(x_train_s, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_features': [2, 4, 6, 8],
#                          'n_estimators': [3, 10, 30]},
#              return_train_score=True, scoring='neg_mean_squared_error')

# %%
best_forest_regressor = grid_search.best_estimator_
best_forest_regressor
# Out:
# RandomForestRegressor(max_features=4, n_estimators=30)

# %%
best_forest_regressor.score(X_test_s, Y_test)
# Out:
# 0.55370876305601

# %% [markdown]
# <h1><strong>How Building Area Affects House Prices - Clustering Model</strong></h1>

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# <strong>Getting the already preprocessed Data</strong>

# %%
new_data = pd.read_csv("database/csv2.csv")
new_data.head()
# Out:
#        Suburb              Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      25 Bloomburg St      2    h  1035000.0      S  Biggin
# 1  Abbotsford         5 Charles St      3    h  1465000.0     SP  Biggin
# 2  Abbotsford          55a Park St      4    h  1600000.0     VB  Nelson
# 3  Abbotsford         16 Maugie St      4    h   870000.0     SN  Nelson
# 4  Abbotsford  121/56 Nicholson St      2    u   870000.0     PI  Biggin
#
#          Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  2016-02-04       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 1  2017-03-04       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 2  2016-06-04       2.5    3067.0  ...       1.0  2.0     120.0         142.0
# 3  2016-08-06       2.5    3067.0  ...       2.0  2.0     400.0         220.0
# 4  2016-11-07       2.5    3067.0  ...       2.0  1.0    4292.0          82.0
#
#    YearBuilt         CouncilArea Lattitude  Longtitude             Regionname  \
# 0     1900.0  Yarra City Council  -37.8079    144.9934  Northern Metropolitan
# 1     1900.0  Yarra City Council  -37.8093    144.9944  Northern Metropolitan
# 2     2014.0  Yarra City Council  -37.8072    144.9941  Northern Metropolitan
# 3     2006.0  Yarra City Council  -37.7965    144.9965  Northern Metropolitan
# 4     2009.0  Yarra City Council  -37.8078    144.9965  Northern Metropolitan
#
#   Propertycount
# 0        4019.0
# 1        4019.0
# 2        4019.0
# 3        4019.0
# 4        4019.0
#
# [5 rows x 21 columns]

# %% [markdown]
# <strong>Ploting Scatter Plot Chart</strong>

# %%
plt.figure(figsize=(50, 20))
plt.scatter(new_data['Price'], new_data['BuildingArea'])
plt.xlabel("Landsize")
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %%
km = KMeans(n_clusters=3)
km
# Out:
# KMeans(n_clusters=3)

# %%
y_predicted =  km.fit_predict(new_data[['BuildingArea', 'Price']])
y_predicted
# Out:
# array([2, 0, 0, ..., 2, 2, 2])

# %%
new_data['cluster'] = y_predicted
new_data.head()
# Out:
#        Suburb              Address  Rooms Type     Price Method SellerG  \
# 0  Abbotsford      25 Bloomburg St      2    h  0.532078      S  Biggin
# 1  Abbotsford         5 Charles St      3    h  0.785168     SP  Biggin
# 2  Abbotsford          55a Park St      4    h  0.864626     VB  Nelson
# 3  Abbotsford         16 Maugie St      4    h  0.434962     SN  Nelson
# 4  Abbotsford  121/56 Nicholson St      2    u  0.434962     PI  Biggin
#
#          Date  Distance  Postcode  ...  Landsize  BuildingArea  YearBuilt  \
# 0  2016-02-04       2.5    3067.0  ...  0.003645          79.0     1900.0
# 1  2017-03-04       2.5    3067.0  ...  0.003131         150.0     1900.0
# 2  2016-06-04       2.5    3067.0  ...  0.002804         142.0     2014.0
# 3  2016-08-06       2.5    3067.0  ...  0.009346         220.0     2006.0
# 4  2016-11-07       2.5    3067.0  ...  0.100280          82.0     2009.0
#
#           CouncilArea  Lattitude  Longtitude             Regionname  \
# 0  Yarra City Council   -37.8079    144.9934  Northern Metropolitan
# 1  Yarra City Council   -37.8093    144.9944  Northern Metropolitan
# 2  Yarra City Council   -37.8072    144.9941  Northern Metropolitan
# 3  Yarra City Council   -37.7965    144.9965  Northern Metropolitan
# 4  Yarra City Council   -37.8078    144.9965  Northern Metropolitan
#
#    Propertycount  cluster scaled_cluster
# 0         4019.0        2              2
# 1         4019.0        0              1
# 2         4019.0        0              1
# 3         4019.0        0              2
# 4         4019.0        2              2
#
# [5 rows x 23 columns]

# %%
dataframe_1 = new_data[new_data.cluster == 0]
dataframe_2 = new_data[new_data.cluster == 1]
dataframe_3 = new_data[new_data.cluster == 2]

plt.figure(figsize= (50, 20))
plt.scatter(dataframe_1.Price, dataframe_1['BuildingArea'], color='green')
plt.scatter(dataframe_2.Price, dataframe_2['BuildingArea'], color='red')
plt.scatter(dataframe_3.Price, dataframe_3['BuildingArea'], color='blue')

plt.xlabel("Landsize")
plt.ylabel("Price")
plt.legend()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_15504\2690696766.py:12: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# <strong>Data Processing anf Scalling (MinMaxScaler)</strong>

# %%
minmaxscaler = MinMaxScaler()
minmaxscaler.fit(new_data[['Price']])
new_data['Price'] = minmaxscaler.transform(new_data['Price'].values.reshape(-1, 1))
# new_data['Price'] = minmaxscaler.transform(new_data[['Price']]) Also works if passed as a dataframe
new_data.head()
# Out:
# d:\Swinburne\Year 2 - Sem 2\Computing Design Innovation Project\Project ENV\.venv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#        Suburb              Address  Rooms Type     Price Method SellerG  \
# 0  Abbotsford      25 Bloomburg St      2    h  0.532078      S  Biggin
# 1  Abbotsford         5 Charles St      3    h  0.785168     SP  Biggin
# 2  Abbotsford          55a Park St      4    h  0.864626     VB  Nelson
# 3  Abbotsford         16 Maugie St      4    h  0.434962     SN  Nelson
# 4  Abbotsford  121/56 Nicholson St      2    u  0.434962     PI  Biggin
#
#          Date  Distance  Postcode  ...  Landsize  BuildingArea  YearBuilt  \
# 0  2016-02-04       2.5    3067.0  ...  0.003645          79.0     1900.0
# 1  2017-03-04       2.5    3067.0  ...  0.003131         150.0     1900.0
# 2  2016-06-04       2.5    3067.0  ...  0.002804         142.0     2014.0
# 3  2016-08-06       2.5    3067.0  ...  0.009346         220.0     2006.0
# 4  2016-11-07       2.5    3067.0  ...  0.100280          82.0     2009.0
#
#           CouncilArea  Lattitude  Longtitude             Regionname  \
# 0  Yarra City Council   -37.8079    144.9934  Northern Metropolitan
# 1  Yarra City Council   -37.8093    144.9944  Northern Metropolitan
# 2  Yarra City Council   -37.8072    144.9941  Northern Metropolitan
# 3  Yarra City Council   -37.7965    144.9965  Northern Metropolitan
# 4  Yarra City Council   -37.8078    144.9965  Northern Metropolitan
#
#    Propertycount  cluster scaled_cluster
# 0         4019.0        2              2
# 1         4019.0        0              1
# 2         4019.0        0              1
# 3         4019.0        0              2
# 4         4019.0        2              2
#
# [5 rows x 23 columns]

# %%
minmaxscaler.fit(new_data[['BuildingArea']])
new_data['BuildingArea'] = minmaxscaler.transform(new_data['BuildingArea'].values.reshape(-1, 1))
new_data.head()
# Out:
# d:\Swinburne\Year 2 - Sem 2\Computing Design Innovation Project\Project ENV\.venv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#        Suburb              Address  Rooms Type     Price Method SellerG  \
# 0  Abbotsford      25 Bloomburg St      2    h  0.532078      S  Biggin
# 1  Abbotsford         5 Charles St      3    h  0.785168     SP  Biggin
# 2  Abbotsford          55a Park St      4    h  0.864626     VB  Nelson
# 3  Abbotsford         16 Maugie St      4    h  0.434962     SN  Nelson
# 4  Abbotsford  121/56 Nicholson St      2    u  0.434962     PI  Biggin
#
#          Date  Distance  Postcode  ...  Landsize  BuildingArea  YearBuilt  \
# 0  2016-02-04       2.5    3067.0  ...  0.003645      0.050609     1900.0
# 1  2017-03-04       2.5    3067.0  ...  0.003131      0.096092     1900.0
# 2  2016-06-04       2.5    3067.0  ...  0.002804      0.090967     2014.0
# 3  2016-08-06       2.5    3067.0  ...  0.009346      0.140935     2006.0
# 4  2016-11-07       2.5    3067.0  ...  0.100280      0.052530     2009.0
#
#           CouncilArea  Lattitude  Longtitude             Regionname  \
# 0  Yarra City Council   -37.8079    144.9934  Northern Metropolitan
# 1  Yarra City Council   -37.8093    144.9944  Northern Metropolitan
# 2  Yarra City Council   -37.8072    144.9941  Northern Metropolitan
# 3  Yarra City Council   -37.7965    144.9965  Northern Metropolitan
# 4  Yarra City Council   -37.8078    144.9965  Northern Metropolitan
#
#    Propertycount  cluster scaled_cluster
# 0         4019.0        2              2
# 1         4019.0        0              1
# 2         4019.0        0              1
# 3         4019.0        0              2
# 4         4019.0        2              2
#
# [5 rows x 23 columns]

# %%
km = KMeans(n_clusters=3)
y_predicted = km.fit_predict(new_data[['Price', 'BuildingArea']])
y_predicted
# Out:
# array([0, 1, 1, ..., 0, 2, 0])

# %%
new_data['scaled_cluster'] = y_predicted
new_data.head()
# Out:
#        Suburb              Address  Rooms Type     Price Method SellerG  \
# 0  Abbotsford      25 Bloomburg St      2    h  0.532078      S  Biggin
# 1  Abbotsford         5 Charles St      3    h  0.785168     SP  Biggin
# 2  Abbotsford          55a Park St      4    h  0.864626     VB  Nelson
# 3  Abbotsford         16 Maugie St      4    h  0.434962     SN  Nelson
# 4  Abbotsford  121/56 Nicholson St      2    u  0.434962     PI  Biggin
#
#          Date  Distance  Postcode  ...  Landsize  BuildingArea  YearBuilt  \
# 0  2016-02-04       2.5    3067.0  ...  0.003645      0.050609     1900.0
# 1  2017-03-04       2.5    3067.0  ...  0.003131      0.096092     1900.0
# 2  2016-06-04       2.5    3067.0  ...  0.002804      0.090967     2014.0
# 3  2016-08-06       2.5    3067.0  ...  0.009346      0.140935     2006.0
# 4  2016-11-07       2.5    3067.0  ...  0.100280      0.052530     2009.0
#
#           CouncilArea  Lattitude  Longtitude             Regionname  \
# 0  Yarra City Council   -37.8079    144.9934  Northern Metropolitan
# 1  Yarra City Council   -37.8093    144.9944  Northern Metropolitan
# 2  Yarra City Council   -37.8072    144.9941  Northern Metropolitan
# 3  Yarra City Council   -37.7965    144.9965  Northern Metropolitan
# 4  Yarra City Council   -37.8078    144.9965  Northern Metropolitan
#
#    Propertycount  cluster scaled_cluster
# 0         4019.0        2              0
# 1         4019.0        0              1
# 2         4019.0        0              1
# 3         4019.0        0              0
# 4         4019.0        2              0
#
# [5 rows x 23 columns]

# %% [markdown]
# <strong>Finding Cluster Centroid</strong>

# %%
dataframe_1 = new_data[new_data.cluster == 0]
dataframe_2 = new_data[new_data.cluster == 1]
dataframe_3 = new_data[new_data.cluster == 2]

plt.figure(figsize= (50, 20))
plt.scatter(dataframe_1.Price, dataframe_1['BuildingArea'], color='green')
plt.scatter(dataframe_2.Price, dataframe_2['BuildingArea'], color='red')
plt.scatter(dataframe_3.Price, dataframe_3['BuildingArea'], color='blue')

plt.scatter(km.cluster_centers_[:, 0], km.cluster_centers_[:, 1], color='black', marker='*', label='Centroid')

plt.xlabel("Price")
plt.ylabel("Building Area")
plt.legend()

# %% [markdown]
# <strong>Elbow Plot</strong>

# %%
km.cluster_centers_
# Out:
# array([[0.4457487 , 0.09979389],
#        [0.7683569 , 0.10903556],
#        [0.24334354, 0.06695875]])

# %%
k_range = range(1, 10)
sse = []
for k in k_range:
    km = KMeans(n_clusters=k)
    km.fit(new_data[['Price', 'Distance']])
    sse.append(km.inertia_)

# %%
sse
# Out:
# [512298.8782446218,
#  205280.16608468193,
#  98459.47109212575,
#  56646.326055224185,
#  37720.82650359479,
#  26793.10547938196,
#  23028.915835501757,
#  17783.014987136674,
#  12516.788850582463]

# %%
plt.xlabel('K')
plt.ylabel('SSE')
plt.plot(k_range, sse)
